# %%
import pandas as pd
df = pd.read_csv("../data_set.csv")

# %%
df.head()

# %%
df.tail()

# %%
df.info()

# %%
df.describe()

# %%
df.columns

# %%
df["Age"] #works, gives the Age column
type(df["Gender"])

# %%
df[55] #don't work, as it can't give 55th row directly, instead it would start looking for column named 55, but...
df[55:89] #works, when slicing used, it gives entire rows! so you can kinda take whatever entire row using>>
df[44:45] #this will only give 44th row..

# %%
print(df[["Age"]])#  #works, but when a list is passed, it makes a new data-frame of the given columns, and more columns could be passed too..as 
len(df[["Age","Gender"]])#

# %%
print(type(df["Gender"]))
print(type(df["Gender"][8]))
df["Gender"][4]
# Out:
# <class 'pandas.core.series.Series'>
# <class 'str'>
# 'Male'

# %%
df.iloc(0)
type(df.iloc(0))
# Out:
# pandas.core.indexing._iLocIndexer

# %%
print(len(df[(df["Gender"] == "Female") & (df["Age"]<20)]))
# Out:
# 24

# %%
df.iloc(1).__dict__["axis"]
list(df.iloc[0])
df.iloc[0]["Gender"]
# Out:
# 'Male'

# %%
obj = df["Gender"] == "Male"
df[obj][55:66]
df[55:66][obj]

# %%
newdf = df[ (df["Transaction ID"] == 53) & (df["Product Category"] == "Electronics")]["Age"] = 88
#it was only changed in the copy of the data frame..
print(newdf)

# %%
df.groupby("Age")["Total Amount"].sum().sort_values()

# %%
df = pd.read_csv("../data_set.csv")
